# %%
import sqlite3
import pandas as pd

# %%
conn = sqlite3.connect('/data3/ams560-f24/mimic_iv/mimic4.db')
cur = conn.cursor()

# %%
df = pd.read_sql_query("""select * from 'hosp/patients' pat join 'hosp/admissions' adm
         on pat.subject_id = adm.subject_id
         order by pat.subject_id
         limit 100;""", conn)

# %%
df.describe()
# Out:
#               los
# count  100.000000
# mean     3.530000
# std      3.267393
# min      1.000000
# 25%      1.000000
# 50%      2.500000
# 75%      4.000000
# max     18.000000

# %%
df
# Out:
#    subject_id gender anchor_age anchor_year anchor_year_group         dod  \
# 0    10000032      F         52        2180       2014 - 2016  2180-09-09
# 1    10000032      F         52        2180       2014 - 2016  2180-09-09
# 2    10000032      F         52        2180       2014 - 2016  2180-09-09
# 3    10000032      F         52        2180       2014 - 2016  2180-09-09
# 4    10000068      F         19        2160       2008 - 2010
# ..        ...    ...        ...         ...               ...         ...
# 95   10001884      F         68        2122       2008 - 2010  2131-01-20
# 96   10001884      F         68        2122       2008 - 2010  2131-01-20
# 97   10001919      M         59        2124       2017 - 2019  2124-12-20
# 98   10002012      F         19        2167       2011 - 2013
# 99   10002013      F         53        2156       2008 - 2010
#
#    subject_id   hadm_id            admittime            dischtime  ...  \
# ...

# %%
df.columns
