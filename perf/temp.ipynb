# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
n1 = pd.read_csv("neo4j_r1.txt", header=None)
n2 = pd.read_csv("neo4j_r2.txt", header=None)

n3 = pd.read_csv("neo4j_r4.txt", header=None)
n4 = pd.read_csv("neo4j_r3.txt", header=None)

n5 = pd.read_csv("neo4j_r5.txt", header=None)
n6 = pd.read_csv("neo4j_r6.txt", header=None)


# r = pd.read_csv("results.csv", header=None)

# %%
n4
# Out:
#                      0    1   2
# 0    [<Record agg=1>]    63   1
# 1    [<Record agg=1>]   128   1
# 2    [<Record agg=1>]    43   0
# 3    [<Record agg=1>]    33   0
# 4    [<Record agg=0>]    20   0
# 5    [<Record agg=0>]     2   0
# 6   [<Record agg=17>]    79   1
# 7   [<Record agg=91>]     1  17
# 8    [<Record agg=9>]     0  15
# 9   [<Record agg=25>]     1  31
# 10  [<Record agg=38>]    41   0
# 11   [<Record agg=0>]    63   1
# 12   [<Record agg=0>]     3   1
# 13   [<Record agg=0>]     2   1
# 14   [<Record agg=0>]     3   1
# 15   [<Record agg=0>]     2   1
# 16   [<Record agg=0>]     2   0
# 17   [<Record agg=0>]     2   1
# 18   [<Record agg=0>]     2   0
# 19   [<Record agg=0>]     3   0
# 20   [<Record agg=0>]     2   1
# 21   [<Record agg=0>]    60   1
# 22   [<Record agg=1>]     4   1
# 23   [<Record agg=0>]     3   1
# 24   [<Record agg=0>]     2   0
# 25   [<Record agg=0>]     2   1
# 26   [<Record agg=0>]     3   1
# 27   [<Record agg=1>]     2   1
# ...

# %%
plt.figure(figsize=(10, 6))

# First dataframe
plt.plot(n1[1], label='C3 AVBL')
# plt.plot(n1[2], label='C3 PROC')

# # third dataframe 
# plt.plot(n2[1], label='C3 AVBL CACHE')
# plt.plot(n2[2], label='C3 PROC CACHE')

# First dataframe
plt.plot(n3[1], label='C2 AVBL')
# plt.plot(n3[2], label='C2 PROC')

# # third dataframe 
# plt.plot(n4[1], label='C2 AVBL CACHE')
# plt.plot(n4[2], label='C2 PROC CACHE')

# First dataframe
plt.plot(n5[1], label='C1 AVBL')
# plt.plot(n5[2], label='C1 PROC')

# # third dataframe 
# plt.plot(n6[1], label='C1 AVBL CACHE')
# plt.plot(n6[2], label='C1 PROC CACHE')



plt.ylim(top=60)

# Customize the plot
plt.xlabel('Query #')
plt.ylabel('Time (ms)')
plt.title('Comparison of time taken to run queries on both systems')
plt.legend()
plt.grid(True)

# Display the plot
plt.show()
